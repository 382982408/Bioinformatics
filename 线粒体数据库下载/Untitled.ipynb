# %%
import pandas as pd

# %%
df = pd.read_html("http://www.mtdb.igp.uu.se/Polysites/andpoly_3.html")

# %%
df_site = df[2]
df_site.head()
# Out:
#       0               1     2     3    4     5    6         7      8   \
# 0    CRS  2704 Sequences   NaN   NaN  NaN   NaN  NaN       NaN    NaN
# 1  Posn.            Base     A     G    C     T  Gap  Location  Codon
# 2   2010               T   NaN   NaN    1  2703  NaN  16S rRNA    NaN
# 3   2045               A  2699     5  NaN   NaN  NaN  16S rRNA    NaN
# 4   2056               G     6  2698  NaN   NaN  NaN  16S rRNA    NaN
#
#          9             10    11
# 0       NaN           NaN   NaN
# 1  Position  Amino Change  Syn?
# 2       NaN           NaN   NaN
# 3       NaN           NaN   NaN
# 4       NaN           NaN   NaN

# %%
pd.DataFrame.loc??

# %%
df_site.columns = list(df[2].iloc[1])

# %%
df_site.head()
# Out:
#    Posn.            Base     A     G    C     T  Gap  Location  Codon  \
# 0    CRS  2704 Sequences   NaN   NaN  NaN   NaN  NaN       NaN    NaN
# 1  Posn.            Base     A     G    C     T  Gap  Location  Codon
# 2   2010               T   NaN   NaN    1  2703  NaN  16S rRNA    NaN
# 3   2045               A  2699     5  NaN   NaN  NaN  16S rRNA    NaN
# 4   2056               G     6  2698  NaN   NaN  NaN  16S rRNA    NaN
#
#    Position  Amino Change  Syn?
# 0       NaN           NaN   NaN
# 1  Position  Amino Change  Syn?
# 2       NaN           NaN   NaN
# 3       NaN           NaN   NaN
# 4       NaN           NaN   NaN

# %%
df_site.loc[2:].head()
# Out:
#   Posn. Base     A     G     C     T  Gap  Location Codon Position  \
# 2  2010    T   NaN   NaN     1  2703  NaN  16S rRNA   NaN      NaN
# 3  2045    A  2699     5   NaN   NaN  NaN  16S rRNA   NaN      NaN
# 4  2056    G     6  2698   NaN   NaN  NaN  16S rRNA   NaN      NaN
# 5  2060    A  2703     1   NaN   NaN  NaN  16S rRNA   NaN      NaN
# 6  2061    C   NaN   NaN  2703     1  NaN  16S rRNA   NaN      NaN
#
#   Amino Change Syn?
# 2          NaN  NaN
# 3          NaN  NaN
# 4          NaN  NaN
# 5          NaN  NaN
# 6          NaN  NaN

# %%
df_site[2:].head()
# Out:
#   Posn. Base     A     G     C     T  Gap  Location Codon Position  \
# 2  2010    T   NaN   NaN     1  2703  NaN  16S rRNA   NaN      NaN
# 3  2045    A  2699     5   NaN   NaN  NaN  16S rRNA   NaN      NaN
# 4  2056    G     6  2698   NaN   NaN  NaN  16S rRNA   NaN      NaN
# 5  2060    A  2703     1   NaN   NaN  NaN  16S rRNA   NaN      NaN
# 6  2061    C   NaN   NaN  2703     1  NaN  16S rRNA   NaN      NaN
#
#   Amino Change Syn?
# 2          NaN  NaN
# 3          NaN  NaN
# 4          NaN  NaN
# 5          NaN  NaN
# 6          NaN  NaN
